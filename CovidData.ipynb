# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Aniket\Documents\Jupyter Notebook\Datasets\covid19.csv")

# %%
data.head()
# Out:
#          Date  Confirmed  Recovered  Deaths  Increase rate
# 0  2020-01-22        555         28      17            NaN
# 1  2020-01-23        654         30      18      17.837838
# 2  2020-01-24        941         36      26      43.883792
# 3  2020-01-25       1434         39      42      52.391073
# 4  2020-01-26       2118         52      56      47.698745

# %%
data.columns
# Out:
# Index(['Date', 'Confirmed', 'Recovered', 'Deaths', 'Increase rate'], dtype='object')

# %%
data.tail()
# Out:
#           Date  Confirmed  Recovered  Deaths  Increase rate
# 75  2020-04-06    1345101     276515   74565       5.737374
# 76  2020-04-07    1426096     300054   81865       6.021481
# 77  2020-04-08    1511104     328661   88338       5.960889
# 78  2020-04-09    1595350     353975   95455       5.575129
# 79  2020-04-10    1691719     376096  102525       6.040618

# %%
data.describe()
# Out:
#           Confirmed      Recovered         Deaths  Increase rate
# count  8.000000e+01      80.000000      80.000000      79.000000
# mean   2.960705e+05   73230.350000   14616.300000      11.425022
# std    4.346123e+05   91158.358234   24870.210118      14.266109
# min    5.550000e+02      28.000000      17.000000       0.491269
# 25%    4.429200e+04    4498.750000    1088.000000       3.043117
# 50%    8.933750e+04   44159.000000    3040.500000       8.135547
# 75%    3.126185e+05   93243.750000   13392.500000      11.947408
# max    1.691719e+06  376096.000000  102525.000000      90.570550

# %%
data.isnull().sum()
# Out:
# Date             0
# Confirmed        0
# Recovered        0
# Deaths           0
# Increase rate    1
# dtype: int64

# %% [markdown]
# # relating the variables with scatterplots

# %%
sns.relplot(x="Confirmed", y="Deaths", hue="Recovered", data=data)

# %%
sns.pairplot(data)
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Aniket\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.relplot(x='Confirmed', y='Deaths', kind='line', data=data)

# %%
sns.catplot(x='Deaths', y='Recovered', data=data)
